# %%
import pandas as pd
import boto3

aws = boto3.Session()
s3 = aws.client("s3")

# bucket = "ds4a-co6-t107-datalake"
# key = "parquetized/department_population_2016_2022.parquet"
filepath = "../data/department_population_2016_2022.parquet"

#obj_bytes = s3.get_object(Bucket=bucket, Key=key).get("Body")
#df = pd.read_parquet(obj_bytes)
df = pd.read_parquet(filepath)
df.head()
# Out:
#    DP         DPNOM   AÑO ÁREA GEOGRÁFICA  Hombres_0  Hombres_1  Hombres_2  \
# 0   5     Antioquia  2016           Total      44860      45056      45267
# 1   8     Atlántico  2016           Total      20771      20937      21038
# 2  11  Bogotá, D.C.  2016           Total      49334      49144      49013
# 3  13       Bolívar  2016           Total      19436      19391      19356
# 4  15        Boyacá  2016           Total       9401       9451       9517
#
#    Hombres_3  Hombres_4  Hombres_5  ...  Total_95  Total_96  Total_97  \
# 0      45508      45787      46109  ...      1715      1511      1607
# 1      21135      21224      21304  ...       705       645       672
# 2      48967      48988      49098  ...      1776      1494      1316
# 3      19333      19324      19325  ...       651       622       624
# 4       9599       9675       9744  ...       526       561       378
#
#    Total_98  Total_99  Total_100 y más  Total Hombres  Total Mujeres    Total  \
# ...

# %%
import io
import boto3
import pyarrow.parquet as pq

buffer = io.BytesIO()
s3 = boto3.resource('s3')
s3_object = s3.Object('ds4a-co6-t107-datalake', 'parquetized/department_population_2016_2022.parquet')
s3_object.download_fileobj(buffer)
table = pq.read_table(buffer)
df = table.to_pandas()
df
# Out:
#      DP         DPNOM   AÑO ÁREA GEOGRÁFICA  Hombres_0  Hombres_1  Hombres_2  \
# 0     5     Antioquia  2016           Total      44860      45056      45267
# 1     8     Atlántico  2016           Total      20771      20937      21038
# 2    11  Bogotá, D.C.  2016           Total      49334      49144      49013
# 3    13       Bolívar  2016           Total      19436      19391      19356
# 4    15        Boyacá  2016           Total       9401       9451       9517
# ..   ..           ...   ...             ...        ...        ...        ...
# 226  91      Amazonas  2022           Total       1012        982        969
# 227  94       Guainía  2022           Total        732        704        684
# 228  95      Guaviare  2022           Total       1004        987        979
# 229  97        Vaupés  2022           Total        789        741        698
# 230  99       Vichada  2022           Total       1469       1443       1415
#
# ...
